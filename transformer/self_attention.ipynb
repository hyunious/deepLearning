# %% [markdown]
# # Self-Attention for transformer

# %% [markdown]
# #### 문맥 이해 (Context Understanding)
# : Self-Attention은 문장 내의 모든 단어가 서로를 참고할 수 있게 하여, 각 단어의 의미를 문맥에 따라 정확하게 파악할 수 있도록 합니다.
#
#
#
# > "The animal didn't cross the street because it was too tired." <br>
# 여기서 **it** 이 가리키는 대상이 *animal* 인지 *street* 인지 문맥을 고려해서 판단해야 합니다. <br>
# Self-Attention은 이런 관계를 파악하는 데 도움을 줍니다.
#
# #### 정보 통합 (Information Integration)
# : 각 단어의 표현을 생성할 때, 전체 문장에서 중요한 단어들의 정보를 가중치를 두어 반영함으로써 더 풍부하고 정교한 표현을 만듭니다. <br>
# 즉, 각 단어를 개별적으로 해석하는 것이 아니라, 문장 전체의 맥락을 고려하여 의미를 구성해 줍니다.

# %% [markdown]
# ----
#
# ### Tokenizer Example
#
# 윌리엄 셰익스피어의 The Sonnets(소네트집) 시집을 토큰화하고 Word Bag 으로 만들어 봅니다.
#
# ###### 해당 시집은 14행의 소네트 형식을 가진 총 154편의 시로 사랑, 시간, 아름다움, 죽음, 질투, 배신 등 인간의 감정과 삶의 깊은 주제들을 다루고 있습니다.
#
# ### Reference:
# 1. https://wikidocs.net/166796
# 2. https://huggingface.co/learn/llm-course/ko/chapter2/4?fw=pt
#
# torchtext 설치시 에러가 발생하여 직접 파싱하는 것으로 대체 <br>
# Hunggingface 신경망 라이브러리 설치 필요..
#
# > pip install transformers

# %%
import torch
from transformers import AutoTokenizer

# 파일 읽기
with open('shakespeare.txt', 'r') as file:
  text = file.read()

# 토큰나이저 생성
tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')

# 행 단위로 분리 (+소문자로 변환)
lines = text.split('\n')
lines = [line.lower().strip() for line in lines if line.strip()]  # 빈 줄 제거

# 각 행을 토큰화하고 결과를 저장
all_tokens = []
for line in lines:
  all_tokens.extend(line.split())
  # all_tokens.extend(tokenizer.tokenize(line))

    
# 토큰 집합 생성 (중복 제거)
unique_tokens = set(all_tokens)

# %%
stoi = {s:i for i, s in enumerate(unique_tokens)}
itos = {i:s for i, s in enumerate(unique_tokens)}

print(stoi)
print(itos)

vocab_size = len(unique_tokens)
print(f"vocabulary size: {vocab_size}")
# Out:
# {'undivided': 0, "learned's": 1, 'spacious,': 2, 'self,': 3, 'become': 4, 'after-loss:': 5, 'thinking': 6, 'over-plus,': 7, 'grecian': 8, 'advance': 9, 'never-resting': 10, 'toward': 11, 'trust,': 12, 'translate!': 13, 'haply': 14, 'comfort,': 15, "truth's": 16, 'these,': 17, 'plagues,': 18, 'policy': 19, 'deserts': 20, 'shalt': 21, 'a': 22, 'wherefore': 23, 'sing:': 24, 'melancholy.': 25, 'praising': 26, 'wherewith': 27, 'rebuked': 28, "love'.": 29, 'commits,': 30, 'offend': 31, 'added': 32, 'lends': 33, 'transfix': 34, 'strange?': 35, 'fester,': 36, 'gored': 37, 'thus.': 38, 'sword,': 39, 'so!': 40, 'stage': 41, 'giving': 42, 'behold,': 43, 'graced': 44, 'bonds': 45, 'clean': 46, 'brought,': 47, 'other,': 48, 'saint': 49, 'thorns,': 50, "intermixed'?": 51, 'taught': 52, 'witness': 53, 'blessing': 54, 'fortune,': 55, 'fury': 56, 'cloak,': 57, 'on
# {0: 'undivided', 1: "learned's", 2: 'spacious,', 3: 'self,', 4: 'become', 5: 'after-loss:', 6: 'thinking', 7: 'over-plus,', 8: 'grecian', 9: 'advance', 10: 'never-resting', 11: 'toward', 12: 'trust,', 13: 'translate!', 14: 'haply', 15: 'comfort,', 16: "truth's", 17: 'these,', 18: 'plagues,', 19: 'policy', 20: 'deserts', 21: 'shalt', 22: 'a', 23: 'wherefore', 24: 'sing:', 25: 'melancholy.', 26: 'praising', 27: 'wherewith', 28: 'rebuked', 29: "love'.", 30: 'commits,', 31: 'offend', 32: 'added', 33: 'lends', 34: 'transfix', 35: 'strange?', 36: 'fester,', 37: 'gored', 38: 'thus.', 39: 'sword,', 40: 'so!', 41: 'stage', 42: 'giving', 43: 'behold,', 44: 'graced', 45: 'bonds', 46: 'clean', 47: 'brought,', 48: 'other,', 49: 'saint', 50: 'thorns,', 51: "intermixed'?", 52: 'taught', 53: 'witness', 54: 'blessing', 55: 'fortune,', 56: 'fury', 57: 'cloak,', 58: 'onward', 59: 'cure,', 60: "men's:", 61: 'heinous', 62: 'limbecks', 63: 'took.', 64: 'invoked', 65: 'uttering', 66: "'truth", 67: 'vows,', 68: 'allow,', 69: "lily's", 70: 'kings,', 71: '(making', 72: 'inward', 73: 'tenure', 74: 'desired,', 75: 'as', 76: 'herald', 77: 'now,', 78: 'bell', 79: 'tend,', 80: 'voices,', 81: 'waiting', 82: 'ten', 83: "april's", 84: 'ornament', 85: 'vengeful', 86: 'fiery', 87: 'fleece', 88: 'blindness,', 89: 'constancy,', 90: 'provoke', 91: 'razed', 92: 'chance,', 93: 'look', 94: 'praise,', 95: 'chief,', 96: 'rigour', 97: 'lack', 98: 'call,', 99: 'lost', 100: 'rich-proud', 101: 'merit', 102: 'strained', 103: 'misuse', 104: 'devour', 105: "tyrants'", 106: 'truest', 107: 'raven', 108: 'costs,', 109: 'rhyme,', 110: 'olives', 111: "infant's", 112: 'he,', 113: 'earth,', 114: 'knife', 115: 'stopped', 116: 'conspire,', 117: 'beguile', 118: 'stands', 119: '(being', 120: 'west,', 121: 'approve', 122: 'bath', 123: 'debateth', 124: 'finds,', 125: 'wrongs,', 126: 'storm-beaten', 127: "o'er-read,", 128: 'is', 129: "'tis", 130: 'imperfect', 131: 'stirred', 132: 'great', 133: 'out.', 134: 'age)', 135: 'green,', 136: 'bird,', 137: 'bliss', 138: 'forbear', 139: 'adieu.', 140: 'kinds', 141: 'were,', 142: 'bevel;', 143: 'long,', 144: 'surmise,', 145: 'mountain', 146: 'barren', 147: 'o', 148: 'profound', 149: 'neck', 150: 'posterity?', 151: 'boast.', 152: 'grief', 153: 'sunken', 154: 'title', 155: 'gazing', 156: 'debarred', 157: "th'", 158: 'have', 159: 'drink', 160: 'lifts', 161: "ow'st,", 162: 'light,', 163: 'fitted', 164: 'duty', 165: 'alone', 166: 'esteeming,', 167: 'must', 168: 'such', 169: 'proved', 170: 'given', 171: 'after', 172: 'prophecies', 173: 'steeled', 174: 'speechless', 175: 'store,', 176: 'her.', 177: 'ills', 178: 'inviting', 179: 'up', 180: 'enlarged,', 181: 'vermilion', 182: 'grows', 183: 'new,', 184: "rud'st", 185: "there's", 186: 'maturity,', 187: 'friend', 188: "friend's", 189: 'strange,', 190: 'remain', 191: 'rebel', 192: 'ground:', 193: 'her', 194: 'render', 195: 'sighs', 196: 'fulfil.', 197: 'fashion,', 198: 'store.', 199: 'pain.', 200: 'reeks.', 201: 'imaginary', 202: 'remains.', 203: 'progress', 204: 'tibey', 205: 'contracted', 206: 'vice', 207: 'treasure,', 208: 'pricked', 209: 'plea', 210: 'departest,', 211: 'accidents', 212: 'writ', 213: 'sweet', 214: 'pencil,', 215: 'preserve', 216: 'poverty', 217: 'rude,', 218: 'rite,', 219: 'tract', 220: '(once', 221: 'charter', 222: 'shore,', 223: 'riches', 224: 'forfeit,', 225: 'prove', 226: "gild'st", 227: '(i', 228: 'pilgrimage:', 229: 'more:', 230: 'willing', 231: 'looks,', 232: 'made:', 233: 'worths', 234: 'quill,', 235: 'unknown,', 236: 'to-morrow', 237: 'those.', 238: 'hanging', 239: 'fragrant', 240: 'gluttoning', 241: 'view.', 242: 'might:', 243: "gav'st", 244: 'mind', 245: 'well?', 246: 'coming', 247: 'antiquity,', 248: 'asleep,', 249: 'race,', 250: 'violet', 251: 'devouring', 252: 'descriptions', 253: "who's", 254: 'one,', 255: 'journey', 256: 'darkly', 257: 'rest.', 258: 'pursuing', 259: 'pleasures', 260: 'exceeded', 261: 'impediments,', 262: 'habit', 263: 'badges', 264: 'chide', 265: 'expired.', 266 ...
# vocabulary size: 4295

# %%
sentence = "i love you all"
indices = [stoi[word] for word in sentence.split()]
print(indices)

# 단어(토큰)의 정수 인덱스를 학습 가능한 고정된 차원의 연속적인 벡터로 변환
import torch.nn as nn

embedding_dim = 20
# num_embeddings : 단어사전 크기, embedding_dim: 벡터 크기
embedding = nn.Embedding(num_embeddings=vocab_size, embedding_dim=embedding_dim)

# 모델이 인식할 수 있는 밀집-벡터(dense vector)로 변환
embedded_sentence = embedding(torch.tensor(indices))
print(embedded_sentence)
# Out:
# [2371, 1173, 793, 1026]
# tensor([[ 0.2477, -0.3313,  1.1064, -0.6326,  1.3194,  0.3778, -2.0814, -0.1527,
#          -1.5948,  1.9727, -1.2865, -0.1500,  0.9934, -0.2072,  1.0374,  0.1523,
#          -0.0651,  1.9234, -0.0882,  0.0619],
#         [-0.1817, -1.6515,  0.0729, -0.9888, -0.6481, -0.6246, -0.4648,  2.0878,
#           1.6984,  1.1344,  1.5739, -0.4028,  0.4333, -1.8122, -0.1278,  1.0623,
#           0.3865,  0.0285,  1.5913, -1.3778],
#         [-2.1732,  1.2798,  0.5358,  0.9157, -0.1282,  1.6348, -0.4856, -0.3346,
#           1.3432,  2.0499,  0.5895, -1.2461, -0.7613, -0.9553, -1.4177, -0.5039,
#          -0.2066,  1.3432,  1.1464,  0.3351],
#         [ 1.5128,  0.0762,  0.1162, -0.2121, -0.1614,  1.3643, -0.2853,  1.2711,
#           0.4427,  0.2444, -0.1347,  0.8433,  0.3167, -0.1238, -0.9987, -0.1086,
#          -1.4123, -0.1227, -1.6816,  1.0898]], grad_fn=<EmbeddingBackward0>)
